# %% [markdown]
# Required Libraries:

# %%
from itertools import groupby
import requests
import zipfile
import os
from io import BytesIO
import pandas as pd
import glob
import pickle
import urllib.request

# %% [markdown]
# PART I

# %% [markdown]
# Download data for years 1990 - 2021 on football teams scores
# Extract Data
# 1. Download zip file that contains multiple subfolders with the scv files
# 2. Extract zip file content
# 3. Remove zip file after
# 4. Read multiple scv files into one dataframe

# %%
link1 = "https://aicore-files.s3.amazonaws.com/Data-Science/Football.zip"
req=requests.get(link1)
filename=link1.split('/')[-1]
with open(filename,'wb') as output_file:
    output_file.write(req.content)

with zipfile.ZipFile(filename,"r") as zip_ref:     
    zip_ref.extractall()

os.remove(filename)

path = "./Results"
csv_files = glob.glob(path + "/**/*.csv", recursive = True)
results_df = [pd.read_csv(f) for f in csv_files]
pd.set_option('display.max_columns', None)
score_df  = pd.concat(results_df, ignore_index=True)
score_df
# Out:
#               Home_Team        Away_Team Result  \
# 0                 Eibar            Celta    0-0
# 1               Granada         Athletic    2-0
# 2                 Cádiz          Osasuna    0-2
# 3                Alavés       Real Betis    0-1
# 4       Real Valladolid      R. Sociedad    1-1
# ...                 ...              ...    ...
# 146636   RBC Roosendaal        Dordrecht    3-2
# 146637          Cambuur       PEC Zwolle    3-3
# 146638      FC Volendam      BV Veendam     2-2
# 146639        Den Bosch      Almere City    1-0
# 146640  Go Ahead Eagles  AGOVV Apeldoorn    2-1
#
#                                                      Link Season Round  \
# 0       https://www.besoccer.com/match/eibar/celta/202...   2021     1
# 1       https://www.besoccer.com/match/granada/athleti...   2021     1
# 2       https://www.besoccer.com/match/cadiz/osasuna/2...   2021     1
# 3       https://www.besoccer.com/match/alaves/betis/20...   2021     1
# 4       https://www.besoccer.com/match/valladolid/real...   2021     1
# ...                                                   ...    ...   ...
# 146636  https://www.besoccer.com/match/rbc/fc-dordrech...   2011    34
# 146637  https://www.besoccer.com/match/sc-cambuur-leeu...   2011    34
# 146638  https://www.besoccer.com/match/fc-volendam/vee...   2011    34
# 146639  https://www.besoccer.com/match/fc-den-bosch/al...   2011    34
# 146640  https://www.besoccer.com/match/go-ahead-eagles...   2011    34
#
#                   League  Unnamed: 0
# 0       primera_division         NaN
# 1       primera_division         NaN
# 2       primera_division         NaN
# 3       primera_division         NaN
# 4       primera_division         NaN
# ...                  ...         ...
# 146636    eerste_divisie       301.0
# 146637    eerste_divisie       302.0
# 146638    eerste_divisie       303.0
# 146639    eerste_divisie       304.0
# 146640    eerste_divisie       305.0
#
# [146641 rows x 8 columns]

# %%
#Display dataframe information
score_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146641 entries, 0 to 146640
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Home_Team   146641 non-null  object
#  1   Away_Team   146641 non-null  object
#  2   Result      146641 non-null  object
#  3   Link        146641 non-null  object
#  4   Season      146641 non-null  object
#  5   Round       146641 non-null  object
#  6   League      146641 non-null  object
#  7   Unnamed: 0  14731 non-null   float64
# dtypes: float64(1), object(7)
# memory usage: 9.0+ MB

# %% [markdown]
# CLEANING DATA
# 1. Change data types for League, Home_Team, Away_Team into category.
# 2. Split Result in form #:# into two columns representing Home Team score and Away Team score.
# 3. Drop columns: Result and extra.
# 4. Drop rows with NA data (see notes).
# 5. Change data types into int for Season (year), Round, and both score columns.
#
# Notes:
# 1. There were only 100 rows of NA data, that has been removed. Not significant.
# 2. DF used memory size droped from 9+MB to 6.3MB

# %%
cols=['League', 'Home_Team','Away_Team']
score_df[cols]=score_df[cols].astype('category')

score_df['Result']=score_df['Result'].astype('string')
score_df[['Home_Score','Away_Score']]=score_df['Result'].str.split('-', expand=True)
score_df['Home_Score'] = pd.to_numeric(score_df['Home_Score'], errors='coerce')
score_df['Away_Score'] = pd.to_numeric(score_df['Away_Score'], errors='coerce')

score_df.drop(['Unnamed: 0', 'Result'], inplace=True, axis=1)
score_df = score_df.dropna()
cols = ['Season', 'Round', 'Home_Score','Away_Score']
score_df[cols]=score_df[cols].astype('int')
score_df
# Out:
# /tmp/ipykernel_46431/1303400552.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score_df[cols]=score_df[cols].astype('int')
#               Home_Team        Away_Team  \
# 0                 Eibar            Celta
# 1               Granada         Athletic
# 2                 Cádiz          Osasuna
# 3                Alavés       Real Betis
# 4       Real Valladolid      R. Sociedad
# ...                 ...              ...
# 146636   RBC Roosendaal        Dordrecht
# 146637          Cambuur       PEC Zwolle
# 146638      FC Volendam      BV Veendam
# 146639        Den Bosch      Almere City
# 146640  Go Ahead Eagles  AGOVV Apeldoorn
#
#                                                      Link  Season  Round  \
# 0       https://www.besoccer.com/match/eibar/celta/202...    2021      1
# 1       https://www.besoccer.com/match/granada/athleti...    2021      1
# 2       https://www.besoccer.com/match/cadiz/osasuna/2...    2021      1
# 3       https://www.besoccer.com/match/alaves/betis/20...    2021      1
# 4       https://www.besoccer.com/match/valladolid/real...    2021      1
# ...                                                   ...     ...    ...
# 146636  https://www.besoccer.com/match/rbc/fc-dordrech...    2011     34
# 146637  https://www.besoccer.com/match/sc-cambuur-leeu...    2011     34
# 146638  https://www.besoccer.com/match/fc-volendam/vee...    2011     34
# 146639  https://www.besoccer.com/match/fc-den-bosch/al...    2011     34
# 146640  https://www.besoccer.com/match/go-ahead-eagles...    2011     34
#
#                   League  Home_Score  Away_Score
# 0       primera_division           0           0
# 1       primera_division           2           0
# 2       primera_division           0           2
# 3       primera_division           0           1
# 4       primera_division           1           1
# ...                  ...         ...         ...
# 146636    eerste_divisie           3           2
# 146637    eerste_divisie           3           3
# 146638    eerste_divisie           2           2
# 146639    eerste_divisie           1           0
# 146640    eerste_divisie           2           1
#
# [146541 rows x 8 columns]

# %%
#memory droped from 9+MB to 6.3MB
score_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146541 entries, 0 to 146640
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Home_Team   146541 non-null  category
#  1   Away_Team   146541 non-null  category
#  2   Link        146541 non-null  object
#  3   Season      146541 non-null  int64
#  4   Round       146541 non-null  int64
#  5   League      146541 non-null  category
#  6   Home_Score  146541 non-null  int64
#  7   Away_Score  146541 non-null  int64
# dtypes: category(3), int64(4), object(1)
# memory usage: 7.4+ MB

# %%
#How many counts per League appeared in data
count1 = score_df.groupby('League')['Home_Team'].count()
print(count1)
# Out:
# League
# 2_liga              10027
# bundesliga           9812
# championship         9321
# eerste_divisie       6485
# eredivisie           9671
# ligue_1             11629
# ligue_2             10888
# premier_league      12416
# primeira_liga        9265
# primera_division    12244
# segunda_division    14038
# segunda_liga         7988
# serie_a              9365
# serie_b             13392
# Name: Home_Team, dtype: int64

# %% [markdown]
# Let's create the dataframe with the data on total number of teams per league

# %%
#Number of unique teams per League
s1 = score_df.groupby('League')['Home_Team'].nunique()
s2 = score_df.groupby('League')['Away_Team'].nunique()

df_league =s1.to_frame(name = 'Home_Team').join(s2.to_frame(name='Away_Team'))
df_league
# Out:
#                   Home_Team  Away_Team
# League
# 2_liga                   83         83
# bundesliga               46         46
# championship             63         63
# eerste_divisie           38         38
# eredivisie               32         32
# ligue_1                  49         49
# ligue_2                  75         75
# premier_league           52         52
# primeira_liga            43         43
# primera_division         51         51
# segunda_division         96         96
# segunda_liga             66         66
# serie_a                  50         50
# serie_b                  87         87

# %% [markdown]
# Next step in analysis is creating a separate dataframe with number of wins/draw/loses for home team each year
# 1. Add new column Wins with the values: 1 for win, 0 for draw and -1 for lose
# 2. New dataframe yearly_trend consists of Season, total games, total wins/draws/loses for home team

# %%
score_df.loc[score_df['Home_Score']==score_df['Away_Score'], 'Wins']=0
score_df.loc[score_df['Home_Score']>score_df['Away_Score'], 'Wins']=1
score_df.loc[score_df['Home_Score']<score_df['Away_Score'], 'Wins']=-1
score_df['Wins']= score_df['Wins'].astype('int')

yearly_trend = pd.DataFrame(
    {
        'total':score_df.groupby('Season')['Wins'].size(),
        'wins' : score_df[score_df['Wins']==1].groupby('Season')['Wins'].size(), 
        'losses' : score_df[score_df['Wins']==-1].groupby('Season')['Wins'].size(),
        'draw' : score_df[score_df['Wins']==0].groupby('Season')['Wins'].size()
    })
yearly_trend
# Out:
# /tmp/ipykernel_46431/2263193985.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score_df.loc[score_df['Home_Score']==score_df['Away_Score'], 'Wins']=0
# /tmp/ipykernel_46431/2263193985.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score_df['Wins']= score_df['Wins'].astype('int')
#         total  wins  losses  draw
# Season
# 1990     4056  1981     814  1261
# 1991     4130  1978     792  1360
# 1992     3964  1885     848  1231
# 1993     4310  2050     971  1289
# 1994     4600  2223     995  1382
# 1995     4526  2145    1018  1363
# 1996     4526  2143    1058  1325
# 1997     4830  2258    1169  1403
# 1998     5064  2447    1195  1422
# 1999     4676  2182    1131  1363
# 2000     4676  2239    1132  1305
# 2001     4676  2264    1159  1253
# 2002     4977  2361    1273  1343
# 2003     4750  2213    1203  1334
# 2004     5267  2414    1350  1503
# 2005     4868  2256    1267  1345
# 2006     4733  2181    1248  1304
# 2007     4602  2136    1207  1259
# 2008     4602  2090    1188  1324
# 2009     4602  2141    1203  1258
# 2010     4586  2118    1224  1244
# 2011     4528  2106    1170  1252
# 2012     4528  2101    1227  1200
# 2013     4680  2095    1296  1289
# 2014     4824  2187    1370  1267
# 2015     4600  2056    1233  1311
# 2016     4600  2026    1296  1278
# 2017     4510  2090    1203  1217
# 2018     4428  2014    1267  1147
# 2019     4234  1907    1206  1121
# 2020     4413  2004    1260  1149
# 2021     4175  1679    1362  1134

# %% [markdown]
# TOTAL goals up to date by team by season

# %%
home_team=score_df[['Home_Team','Home_Score','Wins']]
home_team=home_team.rename(columns={"Home_Team": "Team", "Home_Score": "Score"})
away_team=score_df[['Away_Team', 'Away_Score', 'Wins']]
away_team=away_team.rename(columns={"Away_Team": "Team", "Away_Score": "Score"})
away_team=away_team.replace({'Wins': {-1: 1, 1: -1}})
team_stat=pd.concat([home_team, away_team])
team_stat.groupby('Team').sum().sort_values(by=['Score'], ascending=False)
# Out:
#                 Score  Wins
# Team
# Barcelona        2778   581
# Ajax             2652   571
# Real Madrid      2646   545
# PSV              2612   569
# Bayern München   2380   517
# ...               ...   ...
# Ol. Moscavide      26   -10
# Carregado          26   -12
# UD Logroñés        25    -5
# Licata             22   -10
# CA Bastia          21   -18
#
# [551 rows x 2 columns]

# %% [markdown]
# PART II

# %% [markdown]
# Download new dataframe with the match data: season, red cards, yellow cards, per team (home or away)
# The dataframe uploaded and managed initially by ELO_api module

# %%
link2= 'https://aicore-files.s3.amazonaws.com/Data-Science/Match_Info.csv'
match_df = pd.read_csv(link2)
pd.set_option('display.max_columns', None)
match_df
# Out:
#                                                      Link  \
# 0             /match/saarbrucken/stuttgarter-kickers/1990
# 1                    /match/sc-freiburg/unterhaching/1990
# 2                        /match/vfl-osnabruck/meppen/1990
# 3                  /match/rot-weiss-essen/schalke-04/1990
# 4               /match/alemannia-aachen/msv-duisburg/1990
# ...                                                   ...
# 143343             /match/sunderland-afc/oxford-city/1999
# 143344                     /match/fc-gueugnon/bastia/1994
# 143345          /match/tranmere-rovers/wolverhampton/1999
# 143346                       /match/sochaux/guingamp/2021
# 143347  /match/huddersfield-town-fc/crystal-palace-fc/...
#
#                                   Date_New  \
# 0            Saturday, 29 July 1989, 15:00
# 1            Saturday, 29 July 1989, 15:00
# 2            Saturday, 29 July 1989, 15:00
# 3            Saturday, 29 July 1989, 15:00
# 4            Saturday, 29 July 1989, 15:00
# ...                                    ...
# 143343  Saturday, 19 September 1998, 00:00
# 143344         Tuesday, 17 May 1994, 00:00
# 143345      Friday, 08 January 1999, 00:00
# 143346   Saturday, 27 February 2021, 19:00
# 143347   Saturday, 05 December 1998, 00:00
#
#                                      Referee  Home_Yellow  Home_Red  \
# 0         \r\nReferee: Hans-Jürgen Weber\r\n          0.0       0.0
# 1               \r\nReferee: Kurt Wittke\r\n          1.0       0.0
# 2            \r\nReferee: Werner Föckler\r\n          3.0       0.0
# 3              \r\nReferee: Heinz Werner\r\n          2.0       0.0
# 4       \r\nReferee: Hans-Peter Dellwing\r\n          1.0       0.0
# ...                                      ...          ...       ...
# 143343        \r\nReferee: Anthony Leake\r\n          1.0       0.0
# 143344      \r\nReferee: Jacques Poulain\r\n          0.0       0.0
# 143345          \r\nReferee: Kevin Lynch\r\n          2.0       0.0
# 143346             \r\nReferee: Baert A.\r\n          0.0       0.0
# 143347          \r\nReferee: George Cain\r\n          1.0       0.0
#
#         Away_Yellow  Away_Red
# 0               3.0       0.0
# 1               0.0       0.0
# 2               2.0       0.0
# 3               2.0       0.0
# 4               1.0       0.0
# ...             ...       ...
# 143343          0.0       0.0
# 143344          0.0       0.0
# 143345          1.0       0.0
# 143346          2.0       0.0
# 143347          1.0       0.0
#
# [143348 rows x 7 columns]

# %%
match_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143348 entries, 0 to 143347
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Link         143348 non-null  object
#  1   Date_New     143348 non-null  object
#  2   Referee      143348 non-null  object
#  3   Home_Yellow  122798 non-null  float64
#  4   Home_Red     122798 non-null  float64
#  5   Away_Yellow  122798 non-null  float64
#  6   Away_Red     122798 non-null  float64
# dtypes: float64(4), object(3)
# memory usage: 7.7+ MB

# %% [markdown]
# Cleaning Data:
# 1. Strip the Referee data to the referees names only and make it a category (set number of referees only).
# 2. Split data columns to only year values to turn into Season.
# 3. Dropped unnecessary columns: the temp ones and Link.
# 4. Changed data type for the yellow and red cards into integers and dropped NW values (see notes).
#
# Notes:
# 1. After data cleaning DF size dropped from 7.7MB+ to 6.5MB.
# 2. There were 20550 rows with NA values, which is 14.3%. NA values would not be beneficial for the analysis, therefore the values were removed.

# %%
match_df['Referee'] = match_df['Referee'].str.strip('\r\nReferee:')
match_df['Link'] = match_df['Link'].str.strip('/match/')

match_df['Home_Team']=match_df['Link'].str.split('/', expand=True)[0]
match_df['Away_Team']=match_df['Link'].str.split('/', expand=True)[1]
match_df['Season']=match_df['Link'].str.split('/', expand=True)[2]

cols=['Link', 'Date_New']
match_df.drop(cols,inplace=True, axis=1)

cols=['Home_Yellow', 'Away_Yellow', 'Home_Red', 'Away_Red']
match_df[cols] = match_df[cols].astype('Int64')

match_df['Referee'] = match_df['Referee'].astype('category')
match_df['Season']=match_df['Season'].astype('category')
#match_df=match_df[match_df['Home_Yellow'].isna()==False]

match_df
# Out:
#                      Referee  Home_Yellow  Home_Red  Away_Yellow  Away_Red  \
# 0            Hans-Jürgen Web            0         0            3         0
# 1                 Kurt Wittk            1         0            0         0
# 2               Werner Föckl            3         0            2         0
# 3                 Heinz Wern            2         0            2         0
# 4        Hans-Peter Dellwing            1         0            1         0
# ...                      ...          ...       ...          ...       ...
# 143343          Anthony Leak            1         0            0         0
# 143344       Jacques Poulain            0         0            0         0
# 143345           Kevin Lynch            2         0            1         0
# 143346              Baert A.            0         0            2         0
# 143347           George Cain            1         0            1         0
#
#                   Home_Team            Away_Team Season
# 0               saarbrucken  stuttgarter-kickers   1990
# 1               sc-freiburg         unterhaching   1990
# 2             vfl-osnabruck               meppen   1990
# 3           rot-weiss-essen           schalke-04   1990
# 4           lemannia-aachen         msv-duisburg   1990
# ...                     ...                  ...    ...
# 143343       sunderland-afc          oxford-city   1999
# 143344          fc-gueugnon               bastia   1994
# 143345       ranmere-rovers        wolverhampton   1999
# 143346              sochaux             guingamp   2021
# 143347  uddersfield-town-fc    crystal-palace-fc   1999
#
# [143348 rows x 8 columns]

# %%
match_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143348 entries, 0 to 143347
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Referee      143348 non-null  category
#  1   Home_Yellow  122798 non-null  Int64
#  2   Home_Red     122798 non-null  Int64
#  3   Away_Yellow  122798 non-null  Int64
#  4   Away_Red     122798 non-null  Int64
#  5   Home_Team    143348 non-null  object
#  6   Away_Team    143348 non-null  object
#  7   Season       143348 non-null  category
# dtypes: Int64(4), category(2), object(2)
# memory usage: 7.6+ MB

# %% [markdown]
# Add pickle file data to the above to get ELO (obtained by scraper in separate module, by following the links from the current file)

# %%
pickle_link='https://aicore-files.s3.amazonaws.com/Data-Science/elo_dict.pkl'
myfile = pickle.load(urllib.request.urlopen(pickle_link))
#myfile=pickle.load(open(pickle_link, 'rb'))
newdf=(pd.DataFrame(myfile)).T
newdf = newdf.rename_axis('Link').reset_index()
newdf['Home_Team']=newdf['Link'].str.split('/', expand=True)[4]
newdf['Away_Team']=newdf['Link'].str.split('/', expand=True)[5]
newdf.drop('Link',inplace=True, axis=1)
newdf
# Out:
#         Elo_home  Elo_away         Home_Team            Away_Team
# 0           56.0      59.0       saarbrucken  stuttgarter-kickers
# 1           53.0      55.0       sc-freiburg         unterhaching
# 2           52.0      53.0     vfl-osnabruck               meppen
# 3           53.0      62.0   rot-weiss-essen           schalke-04
# 4           57.0      52.0  alemannia-aachen         msv-duisburg
# ...          ...       ...               ...                  ...
# 132106      59.0      59.0             lecce            spal-1907
# 132107      58.0      57.0  frosinone-calcio        as-cittadella
# 132108      40.0      49.0           reggina       vicenza-calcio
# 132109      54.0      47.0           venezia        nuova-cosenza
# 132110      64.0      56.0            chievo          pisa-calcio
#
# [132111 rows x 4 columns]

# %% [markdown]
# Merge the match and the new dataframes to combine info, those with empty ELO will be deleted from the base (about 7.8% of the data)

# %%
final_match_df = pd.merge(match_df, newdf,  how='left', left_on=['Home_Team','Away_Team'], right_on = ['Home_Team','Away_Team'])
final_match_df
# Out:
#                   Referee  Home_Yellow  Home_Red  Away_Yellow  Away_Red  \
# 0         Hans-Jürgen Web            0         0            3         0
# 1         Hans-Jürgen Web            0         0            3         0
# 2         Hans-Jürgen Web            0         0            3         0
# 3         Hans-Jürgen Web            0         0            3         0
# 4              Kurt Wittk            1         0            0         0
# ...                   ...          ...       ...          ...       ...
# 1128572          Baert A.            0         0            2         0
# 1128573          Baert A.            0         0            2         0
# 1128574          Baert A.            0         0            2         0
# 1128575          Baert A.            0         0            2         0
# 1128576       George Cain            1         0            1         0
#
#                    Home_Team            Away_Team Season  Elo_home  Elo_away
# 0                saarbrucken  stuttgarter-kickers   1990      56.0      59.0
# 1                saarbrucken  stuttgarter-kickers   1990      58.0      61.0
# 2                saarbrucken  stuttgarter-kickers   1990      56.0      59.0
# 3                saarbrucken  stuttgarter-kickers   1990      40.0      55.0
# 4                sc-freiburg         unterhaching   1990      53.0      55.0
# ...                      ...                  ...    ...       ...       ...
# 1128572              sochaux             guingamp   2021      72.0      62.0
# 1128573              sochaux             guingamp   2021      57.0      62.0
# 1128574              sochaux             guingamp   2021      56.0      62.0
# 1128575              sochaux             guingamp   2021      57.0      59.0
# 1128576  uddersfield-town-fc    crystal-palace-fc   1999       NaN       NaN
#
# [1128577 rows x 10 columns]

# %% [markdown]
# PART III

# %% [markdown]
# Download new file with stadium per team per country

# %%
link3='https://aicore-files.s3.amazonaws.com/Data-Science/Team_Info.csv'
stadium_df = pd.read_csv(link3)
pd.set_option('display.max_columns', None)
stadium_df
# Out:
#                 Team                 City  Country  \
# 0    Wattenscheid 09  Bochum-Wattenscheid  Germany
# 1         Hertha BSC               Berlín  Germany
# 2       Unterhaching         Unterhaching  Germany
# 3       Fortuna Köln              Cologne  Germany
# 4       MSV Duisburg            Duisburgo  Germany
# ..               ...                  ...      ...
# 539           Latina               Latina    Italy
# 540   Virtus Entella             Chiavari    Italy
# 541    Nuova Cosenza              Cosenza    Italy
# 542        Pordenone            Pordenone    Italy
# 543       Bourges 18              Bourges   France
#
#                                 Stadium Capacity              Pitch
# 0                      Lohrheidestadion    16233            Natural
# 1                 Olympiastadion Berlin    76065            Natural
# 2                Sportpark Unterhaching    15053            Natural
# 3                            Südstadion    14944            Natural
# 4             Schauinsland-Reisen-Arena    31514            Natural
# ..                                  ...      ...                ...
# 539  Stadio Comunale Domenico Francioni     8000            Natural
# 540            Stadio Comunale Chiavari     4154  Césped Artificial
# 541                     Stadio San Vito    24209            Natural
# 542                                 NaN     3089                NaN
# 543                                 NaN   13,000                NaN
#
# [544 rows x 6 columns]

# %% [markdown]
# DATA CLEANING
# 1. Country and Pitch is set as a categorical data
# 2. Team, Stadium, City set as strings
# 3. Capacity has some minor data modifications (such as "," to show thousands), so stripped from unnecessary commas and turned into integer data.

# %%
stadium_df['Country']=stadium_df['Country'].astype('category')
stadium_df['Pitch']=stadium_df['Pitch'].astype('category')

cols=['Team', 'Stadium', 'City']
stadium_df[cols]=stadium_df[cols].astype('string')

stadium_df['Capacity'].replace(',','', regex=True, inplace=True)
stadium_df['Capacity'] = pd.to_numeric(stadium_df['Capacity'],errors='coerce')
stadium_df['Capacity']=stadium_df['Capacity'].astype('int')

stadium_df
# Out:
#                 Team                 City  Country  \
# 0    Wattenscheid 09  Bochum-Wattenscheid  Germany
# 1         Hertha BSC               Berlín  Germany
# 2       Unterhaching         Unterhaching  Germany
# 3       Fortuna Köln              Cologne  Germany
# 4       MSV Duisburg            Duisburgo  Germany
# ..               ...                  ...      ...
# 539           Latina               Latina    Italy
# 540   Virtus Entella             Chiavari    Italy
# 541    Nuova Cosenza              Cosenza    Italy
# 542        Pordenone            Pordenone    Italy
# 543       Bourges 18              Bourges   France
#
#                                 Stadium  Capacity              Pitch
# 0                      Lohrheidestadion     16233            Natural
# 1                 Olympiastadion Berlin     76065            Natural
# 2                Sportpark Unterhaching     15053            Natural
# 3                            Südstadion     14944            Natural
# 4             Schauinsland-Reisen-Arena     31514            Natural
# ..                                  ...       ...                ...
# 539  Stadio Comunale Domenico Francioni      8000            Natural
# 540            Stadio Comunale Chiavari      4154  Césped Artificial
# 541                     Stadio San Vito     24209            Natural
# 542                                <NA>      3089                NaN
# 543                                <NA>     13000                NaN
#
# [544 rows x 6 columns]

# %%
stadium_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 544 entries, 0 to 543
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Team      544 non-null    string
#  1   City      544 non-null    string
#  2   Country   544 non-null    category
#  3   Stadium   447 non-null    string
#  4   Capacity  544 non-null    int64
#  5   Pitch     447 non-null    category
# dtypes: category(2), int64(1), string(3)
# memory usage: 19.2 KB

# %% [markdown]
# HY

# %% [markdown]
# HYPOTHESES: what has higher influence of winning the match

# %% [markdown]
# 1. Being the Home_Team
# 2. Plaing in Home_Country
# 3. Capacity of your Home_Statium (spectators-pressure)
# 4. Aggressivness as a playing style (check number of red/yellow cards per game)
# 5.
